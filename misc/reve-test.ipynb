# %%
from braindecode.models import REVE

# Load pre-trained model from Hugging Face Hub
model = REVE.from_pretrained("brain-bzh/reve-base")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 from braindecode.models import REVE
#       2
#       3 # Load pre-trained model from Hugging Face Hub
# ----> 4 model = REVE.from_pretrained("brain-bzh/reve-base")
#       5
#       6 model
#
# File ~/miniconda3/envs/david-saliency/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:88, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84         validate_repo_id(arg_value)
#      86 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
# ---> 88 return fn(*args, **kwargs)
#
# File ~/miniconda3/envs/david-saliency/lib/python3.11/site-packages/huggingface_hub/hub_mixin.py:561, in ModelHubMixin.from_pretrained(cls, pretrained_model_name_or_path, force_download, token, cache_dir, local_files_only, revision, **model_kwargs)
#     558     if cls._hub_mixin_inject_config and "config" not in model_kwargs:
#     559         model_kwargs["config"] = config
# --> 561 instance = cls._from_pretrained(
#     562     model_id=str(model_id),
#     563     revision=revision,
#     564     cache_dir=cache_dir,
#     565     force_download=force_download,
#     566     local_files_only=local_files_only,
#     567     token=token,
#     568     **model_kwargs,
#     569 )
#     571 # Implicitly set the config as instance attribute if not already set by the class
#     572 # This way `config` will be available when calling `save_pretrained` or `push_to_hub`.
#     573 if config is not None and (getattr(instance, "_hub_mixin_config", None) in (None, {})):
#
# File ~/miniconda3/envs/david-saliency/lib/python3.11/site-packages/braindecode/models/base.py:755, in EEGModuleMixin._from_pretrained(cls, model_id, revision, cache_dir, force_download, local_files_only, token, map_location, strict, **model_kwargs)
#     753     hf_constants.SAFETENSORS_SINGLE_FILE = filename
#     754 try:
# --> 755     model = super()._from_pretrained(  # type: ignore
#     756         model_id=model_id,
#     757         revision=revision,
#     758         cache_dir=cache_dir,
#     759         force_download=force_download,
#     760         local_files_only=local_files_only,
#     761         token=token,
#     762         map_location=map_location,
#     763         strict=strict,
#     764         **model_kwargs,
#     765     )
#     766 finally:
#     767     hf_constants.SAFETENSORS_SINGLE_FILE = _orig_safetensors
#
# File ~/miniconda3/envs/david-saliency/lib/python3.11/site-packages/huggingface_hub/hub_mixin.py:775, in PyTorchModelHubMixin._from_pretrained(cls, model_id, revision, cache_dir, force_download, local_files_only, token, map_location, strict, **model_kwargs)
#     760 @classmethod
#     761 def _from_pretrained(
#     762     cls,
#    (...)    772     **model_kwargs,
#     773 ):
#     774     """Load Pytorch pretrained weights and return the loaded model."""
# --> 775     model = cls(**model_kwargs)
#     776     if os.path.isdir(model_id):
#     777         print("Loading weights from local directory")
#
# File ~/miniconda3/envs/david-saliency/lib/python3.11/site-packages/braindecode/models/util.py:62, in track_model_init_kwargs.<locals>.wrapped(self, *args, **kwargs)
#      60         captured_kwargs[name] = value
#      61 self._braindecode_init_kwargs = captured_kwargs
# ---> 62 return init(self, *args, **kwargs)
#
# File ~/miniconda3/envs/david-saliency/lib/python3.11/site-packages/braindecode/models/reve.py:314, in REVE.__init__(self, n_outputs, n_chans, chs_info, n_times, input_window_seconds, sfreq, embed_dim, depth, heads, head_dim, mlp_dim_ratio, use_geglu, freqs, patch_size, patch_overlap, attention_pooling)
#     303 self.ln = nn.LayerNorm(self.embed_dim)  # 4DPE module layernorm
#     305 self.transformer = TransformerBackbone(
#     306     dim=self.embed_dim,
#     307     depth=self.depth,
#    (...)    311     geglu=self.use_geglu,
#     312 )
# --> 314 self._build_head(self.n_outputs)
#     316 if self.use_attention_pooling:
#     317     self.cls_query_token = nn.Parameter(torch.randn(1, 1, self.embed_dim))
#
# File ~/miniconda3/envs/david-saliency/lib/python3.11/site-packages/braindecode/models/base.py:308, in EEGModuleMixin.n_outputs(self)
#     305 @property
#     306 def n_outputs(self) -> int:
#     307     if self._n_outputs is None:
# --> 308         raise ValueError("n_outputs not specified.")
#     309     return self._n_outputs
#
# ValueError: n_outputs not specified.

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model
#
# NameError: name 'model' is not defined
